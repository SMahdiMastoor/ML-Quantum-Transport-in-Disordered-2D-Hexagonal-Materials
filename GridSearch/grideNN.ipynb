# %%
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Load the dataset
data = pd.read_csv('merged_file.csv')

# Features and target
X = data[['W', 'L', 'N', 'nm', 'hop', 'energy']].values  # or .to_numpy()
y = data['LDOS'].values.ravel()  # Use ravel() to ensure y is 1D, which MLPRegressor prefers

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.4, random_state=13
)

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('mlp', MLPRegressor(max_iter=1000, random_state=42))
])


param_grid = {
    'mlp__hidden_layer_sizes': [(50,), (100,), (100, 50)],
    'mlp__activation': ['relu', 'tanh'],
    'mlp__alpha': [0.0001, 0.001],  # L2 regularization
    'mlp__learning_rate_init': [0.001, 0.01]
}

# %%
grid_search = GridSearchCV(
    pipeline,
    param_grid,
    cv=3,
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_train, y_train)

print("Best parameters:", grid_search.best_params_)
print("Best MSE:", -grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=   8.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=   8.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=   9.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=   9.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  11.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  11.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  16.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  19.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  11.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  11.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  11.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  19.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  16.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  14.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  36.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  13.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=   9.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  34.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  35.9s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  35.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  46.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=   9.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=   9.7s
# [CV] END mlp__activation=relu, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  47.8s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  10.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  10.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  10.3s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  17.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  19.6s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  19.2s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  15.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  15.5s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  30.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  14.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  46.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=  17.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  41.1s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  40.0s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  46.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=  17.4s
# [CV] END mlp__activation=relu, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  47.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=  19.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  18.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  20.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  21.7s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  24.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  28.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  27.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  16.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  15.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.001; total time=  15.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  55.5s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  56.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=  22.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  56.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=  19.4s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(50,), mlp__learning_rate_init=0.01; total time=  21.0s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time= 1.1min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  19.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  22.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.001; total time=  22.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  29.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  28.3s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100,), mlp__learning_rate_init=0.01; total time=  33.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time= 1.8min
# [CV] END mlp__activation=tanh, mlp__alpha=0.0001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time= 1.9min
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  54.8s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  56.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.001; total time=  54.6s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  49.1s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  44.9s
# [CV] END mlp__activation=tanh, mlp__alpha=0.001, mlp__hidden_layer_sizes=(100, 50), mlp__learning_rate_init=0.01; total time=  48.5s
# Best parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.0001, 'mlp__hidden_layer_sizes': (100, 50), 'mlp__learning_rate_init': 0.001}
# Best MSE: 0.03793383952584265
